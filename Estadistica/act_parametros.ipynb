# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_baterias = pd.read_excel("./baterias(1).xlsx")

valor_esperado = df_baterias["tiempo_hasta_agotar"].mean()

print("El valor esperado poblacional de la vida útil de las baterías es:", valor_esperado)
# Out:
# El valor esperado poblacional de la vida útil de las baterías es: 0.32416864932174144

# %%
df_software = pd.read_excel("./software.xlsx")

probabilidad_un_intento = len(df_software[df_software["intentos_hasta_resolver"] == 1]) / len(df_software)

print("La probabilidad de resolver el problema en un solo intento es:", probabilidad_un_intento)
# Out:
# La probabilidad de resolver el problema en un solo intento es: 0.31066666666666665

# %%
# Extraer los valores de los datos
valores_baterias = df_baterias["tiempo_hasta_agotar"]
valores_software = df_software["intentos_hasta_resolver"]

# Crear histograma para los datos reales
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(valores_baterias, bins=20, density=True, alpha=0.6, label="Datos reales (baterías)")
plt.title("Histograma de Duración de Baterías")

plt.subplot(1, 2, 2)
plt.hist(valores_software, bins=20, density=True, alpha=0.6, label="Datos reales (software)")
plt.title("Histograma de Intentos de Software")

# Crear histograma teórico de distribución normal
mu, sigma = np.mean(valores_baterias), np.std(valores_baterias)
x_normal = np.linspace(min(valores_baterias), max(valores_baterias), 100)
y_normal = norm.pdf(x_normal, mu, sigma)
plt.subplot(1, 2, 1)
plt.plot(x_normal, y_normal, 'r', label='Distribución normal')

# Crear histograma teórico de distribución exponencial
lambda_param = 1 / np.mean(valores_software)
x_expon = np.linspace(min(valores_software), max(valores_software), 100)
y_expon = expon.pdf(x_expon, scale=1/lambda_param)
plt.subplot(1, 2, 2)
plt.plot(x_expon, y_expon, 'r', label='Distribución exponencial')

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 19
#      17 mu, sigma = np.mean(valores_baterias), np.std(valores_baterias)
#      18 x_normal = np.linspace(min(valores_baterias), max(valores_baterias), 100)
# ---> 19 y_normal = norm.pdf(x_normal, mu, sigma)
#      20 plt.subplot(1, 2, 1)
#      21 plt.plot(x_normal, y_normal, 'r', label='Distribución normal')
#
# NameError: name 'norm' is not defined
