# %%
import pandas as pd
import numpy as np

# %%
# Replace 'your_file.csv' with the actual file path
csv_file_path = './Archivos//denue_inegi_26_.csv'

# Replace 'your_encoding' with the actual encoding of your CSV file
file_encoding = 'iso-8859-1'

# Read the CSV file into a Pandas DataFrame with the specified encoding
df = pd.read_csv(csv_file_path, encoding=file_encoding)
# Out:
# C:\Users\luisr\AppData\Local\Temp\ipykernel_14360\3129288843.py:8: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path, encoding=file_encoding)

# %%
df
# Out:
#              id                          clee  \
# 0       8853689  26018114111000014000000000U1
# 1       6179123  26018112511000101001000000U9
# 2       6865042  26072112511000112001000000S3
# 3       7759547  26033114111001784000000000U7
# 4       9278595  26018114119000262000000000U9
# ...         ...                           ...
# 118976  3902254  26038931610000031000000000U5
# 118977  3920474  26018931610000931000000000U8
# 118978  3923524  26042931610000461000000000U6
# 118979  3918604  26018931610000991000000000U2
# 118980  3920475  26018931610000981000000000U3
#
#                                 nom_estab  \
# 0             LOS BETINGOS SC DE RL DE CV
# 1       11 DE DICIEMBRE DE 1996 SPR DE RI
# 2                     3 SOCIOS SONORENSES
# 3          A GARRA BANDIDO SC DE RL DE CV
# 4                      ACCION ACUACULTURA
# ...                                   ...
# 118976  ZONA ESCOLAR PREESCOLAR NUMERO 27
# 118977  ZONA ESCOLAR PREESCOLAR NUMERO 28
# ...

# %%
df['nombre_act']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df['nombre_act']['Servicios de acceso a computadoras'].value_counts()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
# ...

# %%
cantidad = df['localidad'].value_counts()['Hermosillo']

# %%
cantidad
# Out:
# 35750

# %%
df.columns.values
# Out:
# array(['id', 'clee', 'nom_estab', 'raz_social', 'codigo_act',
#        'nombre_act', 'per_ocu', 'tipo_vial', 'nom_vial', 'tipo_v_e_1',
#        'nom_v_e_1', 'tipo_v_e_2', 'nom_v_e_2', 'tipo_v_e_3', 'nom_v_e_3',
#        'numero_ext', 'letra_ext', 'edificio', 'edificio_e', 'numero_int',
#        'letra_int', 'tipo_asent', 'nomb_asent', 'tipoCenCom',
#        'nom_CenCom', 'num_local', 'cod_postal', 'cve_ent', 'entidad',
#        'cve_mun', 'municipio', 'cve_loc', 'localidad', 'ageb', 'manzana',
#        'telefono', 'correoelec', 'www', 'tipoUniEco', 'latitud',
#        'longitud', 'fecha_alta'], dtype=object)

# %%
df['cve_loc']
# Out:
# 0         365
# 1         186
# 2         186
# 3         262
# 4           1
#          ...
# 118976      1
# 118977      1
# 118978      1
# 118979      1
# 118980      1
# Name: cve_loc, Length: 118981, dtype: int64

# %%
top = df['nombre_act'].value_counts()

# %%
top.head(10)
# Out:
# nombre_act
# Comercio al por menor en tiendas de abarrotes, ultramarinos y misceláneas                                     8850
# Salones y clínicas de belleza y peluquerías                                                                   6015
# Reparación mecánica en general de automóviles y camiones                                                      3099
# Elaboración de tortillas de harina de trigo de forma tradicional                                              2824
# Comercio al por menor en minisupers                                                                           2807
# Restaurantes con servicio de preparación de tacos y tortas                                                    2650
# Asociaciones y organizaciones religiosas                                                                      2374
# Comercio al por menor de cerveza                                                                              2276
# ...
